# %% [markdown]
# # Waternet Example
#
# - Code: https://github.com/tnwei/waternet
# - Original paper: https://arxiv.org/abs/1901.05495

# %% [markdown]
# ## Init network

# %%
import torch
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Make sure you are connected to a GPU instance
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
#drive.mount('/content/drive/MyDrive/BolsaInvestigacao/dataset_recifes')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os, shutil
shutil.rmtree('/content/output_WaterNet/')
os.makedirs('/content/output_WaterNet/', exist_ok=True)

# %%
# Load from torchhub
repo = 'tnwei/waternet'
model = 'waternet'
preprocess, postprocess, model = torch.hub.load(repo, model)
model.eval();
# Out:
# Using cache found in /root/.cache/torch/hub/tnwei_waternet_main

# %% [markdown]
# ## Image example

# %%
data_dir =  "/content/drive/MyDrive/BolsaInvestigacao/dataset_recifes"
from glob import glob
imgs = sorted(glob(data_dir + "/C5_reef/2019_07_water/*") +
              glob(data_dir + "/C5_reef/2019_08_water/*") +
              glob(data_dir + "/C5_reef/2022_10_water/*") +
              glob(data_dir + "/C6_reef/2019_07_water/*") +
              glob(data_dir + "/C6_reef/2019_08_water/*") +
              glob(data_dir + "/C6_reef/2022_10_water/*"))
len(imgs)
# Out:
# 1182

# %%
#%%time
import PIL
from PIL import Image
import numpy as np
i = 0
for rgb_im in imgs:
  #im = Image.open(rgb_im)
  im = cv2.imread(rgb_im)
  im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
  #im.resize((720, 480), Image.LANCZOS)
  #im = np.asarray(im)
  im = cv2.resize(im, (720, 480), interpolation=cv2.INTER_CUBIC)  # Waternet only acepts image size with W/H = 1.5 ratio
  # Inference -> return numpy array (1, 3, H, W)
  rgb_ten, wb_ten, he_ten, gc_ten = preprocess(im)
  out_ten = model(rgb_ten, wb_ten, he_ten, gc_ten)
  out_im = postprocess(out_ten)
  #out_im = Image.fromarray(out_im)
  #out_im.resize((800, 600), Image.LANCZOS)
  #out_im.save("/content/output_WaterNet/"+"out_"+ os.path.basename(rgb_im))
  #out_im = cv2.resize(out_im, (800, 600), interpolation=cv2.INTER_CUBIC)
  out_im = cv2.resize(np.squeeze(out_im), (800, 600), interpolation=cv2.INTER_CUBIC)
  out_im = cv2.cvtColor(out_im, cv2.COLOR_BGR2RGB)
  cv2.imwrite("/content/output_WaterNet/"+"out_"+ os.path.basename(rgb_im), out_im)
  print (f"Processed image: {os.path.basename(rgb_im)}, {i+1}/{len(imgs)}")
  i = i + 1
# Out:
# Processed image: G1515686.JPG 1/1182
# Processed image: G1515687.JPG 2/1182
# Processed image: G1515688.JPG 3/1182
# Processed image: G1515689.JPG 4/1182
# Processed image: G1515690.JPG 5/1182
# Processed image: G1515691.JPG 6/1182
# Processed image: G1515692.JPG 7/1182
# Processed image: G1515693.JPG 8/1182
# Processed image: G1515694.JPG 9/1182
# Processed image: G1515695.JPG 10/1182
# Processed image: G1525696.JPG 11/1182
# Processed image: G1525697.JPG 12/1182
# Processed image: G1525698.JPG 13/1182
# Processed image: G1525699.JPG 14/1182
# Processed image: G1525700.JPG 15/1182
# Processed image: G1525701.JPG 16/1182
# Processed image: G1525702.JPG 17/1182
# Processed image: G1525703.JPG 18/1182
# Processed image: G1525704.JPG 19/1182
# Processed image: G1525705.JPG 20/1182
# Processed image: G1535706.JPG 21/1182
# Processed image: G1535707.JPG 22/1182
# Processed image: G1535708.JPG 23/1182
# Processed image: G1535709.JPG 24/1182
# Processed image: G1535710.JPG 25/1182
# Processed image: G1535711.JPG 26/1182
# Processed image: G1535712.JPG 27/1182
# Processed image: G1535713.JPG 28/1182
# Processed image: G1535714.JPG 29/1182
# Processed image: G1535715.JPG 30/1182
# Processed image: G1545716.JPG 31/1182
# Processed image: G1545717.JPG 32/1182
# Processed image: G1545718.JPG 33/1182
# Processed image: G1545719.JPG 34/1182
# Processed image: G1545720.JPG 35/1182
# Processed image: G1545721.JPG 36/1182
# Processed image: G1545722.JPG 37/1182
# Processed image: G1545723.JPG 38/1182
# Processed image: G1545724.JPG 39/1182
# Processed image: G1545725.JPG 40/1182
# Processed image: G1555726.JPG 41/1182
# Processed image: G1555727.JPG 42/1182
# Processed image: G1555728.JPG 43/1182
# Processed image: G1555729.JPG 44/1182
# Processed image: G1555730.JPG 45/1182
# Processed image: G1555731.JPG 46/1182
# Processed image: G1555732.JPG 47/1182
# Processed image: G1555733.JPG 48/1182
# Processed image: G1555734.JPG 49/1182
# Processed image: G1555735.JPG 50/1182
# Processed image: G1565736.JPG 51/1182
# Processed image: G1565737.JPG 52/1182
# Processed image: G1565738.JPG 53/1182
# Processed image: G1565739.JPG 54/1182
# Processed image: G1565740.JPG 55/1182
# Processed image: G1565741.JPG 56/1182
# Processed image: G1565742.JPG 57/1182
# Processed image: G1565743.JPG 58/1182
# Processed image: G1565744.JPG 59/1182
# Processed image: G1565745.JPG 60/1182
# Processed image: G1575746.JPG 61/1182
# Processed image: G1575754.JPG 62/1182
# Processed image: G1575755.JPG 63/1182
# Processed image: G1585756.JPG 64/1182
# Processed image: G1585757.JPG 65/1182
# Processed image: G1585758.JPG 66/1182
# Processed image: G1585759.JPG 67/1182
# Processed image: G1585760.JPG 68/1182
# Processed image: G1585761.JPG 69/1182
# Processed image: G1585762.JPG 70/1182
# Processed image: G1585763.JPG 71/1182
# Processed image: G1585764.JPG 72/1182
# Processed image: G1585765.JPG 73/1182
# Processed image: G1595766.JPG 74/1182
# Processed image: G1595767.JPG 75/1182
# Processed image: G1595768.JPG 76/1182
# Processed image: G1595769.JPG 77/1182
# Processed image: G1595770.JPG 78/1182
# Processed image: G1595771.JPG 79/1182
# Processed image: G1595772.JPG 80/1182
# Processed image: G1595773.JPG 81/1182
# Processed image: G1595774.JPG 82/1182
# Processed image: G1595775.JPG 83/1182
# Processed image: G1605776.JPG 84/1182
# Processed image: G1605777.JPG 85/1182
# Processed image: G1605778.JPG 86/1182
# Processed image: G1605779.JPG 87/1182
# Processed image: G1605780.JPG 88/1182
# Processed image: G1605781.JPG 89/1182
# Processed image: G1605782.JPG 90/1182
# Processed image: G1605783.JPG 91/1182
# Processed image: G1605784.JPG 92/1182
# Processed image: G1605785.JPG 93/1182
# Processed image: G1615786.JPG 94/1182
# Processed image: G1615787.JPG 95/1182
# Processed image: G1615788.JPG 96/1182
# Processed image: G1615789.JPG 97/1182
# Processed image: G1615790.JPG 98/1182
# Processed image: G1615791.JPG 99/1182
# Processed image: G1615792.JPG 100/1182
# Processed image: G1615793.JPG 101/1182
# Processed image: G1615794.JPG 102/1182
# Processed image: G1615795.JPG 103/1182
# Processed image: G1625796.JPG 104/1182
# Processed image: G1625797.JPG 105/1182
# Processed image: G1625798.JPG 106/1182
# Processed image: G1625799.JPG 107/1182
# Processed image: G1625800.JPG 108/1182
# Processed image: G1625801.JPG 109/1182
# Processed image: G1625802.JPG 110/1182
# Processed image: G1625803.JPG 111/1182
# Processed image: G1625804.JPG 112/1182
# Processed image: G1625805.JPG 113/1182
# Processed image: G1635806.JPG 114/1182
# Processed image: G1635807.JPG 115/1182
# Processed image: G1635808.JPG 116/1182
# Processed image: G1635809.JPG 117/1182
# Processed image: G1635810.JPG 118/1182
# Processed image: G1635811.JPG 119/1182
# Processed image: G1635812.JPG 120/1182
# Processed image: G1635813.JPG 121/1182
# Processed image: G1635814.JPG 122/1182
# Processed image: G1635815.JPG 123/1182
# Processed image: G3869422.JPG 124/1182
# Processed image: G3869423.JPG 125/1182
# Processed image: G3869425.JPG 126/1182
# Processed image: G3869427.JPG 127/1182
# Processed image: G3879429.JPG 128/1182
# Processed image: G3879430.JPG 129/1182
# Processed image: G3879431.JPG 130/1182
# Processed image: G3879432.JPG 131/1182
# Processed image: G3879433.JPG 132/1182
# Processed image: G3879434.JPG 133/1182
# Processed image: G3879435.JPG 134/1182
# Processed image: G3879436.JPG 135/1182
# Processed image: G3879437.JPG 136/1182
# Processed image: G3879438.JPG 137/1182
# Processed image: G3889439.JPG 138/1182
# Processed image: G3889440.JPG 139/1182
# Processed image: G3889441.JPG 140/1182
# Processed image: G3889442.JPG 141/1182
# Processed image: G3889443.JPG 142/1182
# Processed image: G3889444.JPG 143/1182
# Processed image: G3889445.JPG 144/1182
# Processed image: G3889446.JPG 145/1182
# Processed image: G3889447.JPG 146/1182
# Processed image: G3899449.JPG 147/1182
# Processed image: G3899450.JPG 148/1182
# Processed image: G3899451.JPG 149/1182
# Processed image: G3899452.JPG 150/1182
# Processed image: G3899453.JPG 151/1182
# Processed image: G3899454.JPG 152/1182
# Processed image: G3899455.JPG 153/1182
# Processed image: G3899456.JPG 154/1182
# Processed image: G3899457.JPG 155/1182
# Processed image: G3899458.JPG 156/1182
# Processed image: G3909459.JPG 157/1182
# Processed image: G3909460.JPG 158/1182
# Processed image: G3909461.JPG 159/1182
# Processed image: G3909462.JPG 160/1182
# Processed image: G3909463.JPG 161/1182
# Processed image: G3909464.JPG 162/1182
# Processed image: G3909465.JPG 163/1182
# Processed image: G3909466.JPG 164/1182
# Processed image: G3909467.JPG 165/1182
# Processed image: G3909468.JPG 166/1182
# Processed image: G3919469.JPG 167/1182
# Processed image: G3919470.JPG 168/1182
# Processed image: G3919471.JPG 169/1182
# Processed image: G3919472.JPG 170/1182
# Processed image: G3919473.JPG 171/1182
# Processed image: G3919474.JPG 172/1182
# Processed image: G3919475.JPG 173/1182
# Processed image: G3919476.JPG 174/1182
# Processed image: G3919477.JPG 175/1182
# Processed image: G3919478.JPG 176/1182
# Processed image: G3929479.JPG 177/1182
# Processed image: G3929480.JPG 178/1182
# Processed image: G3929481.JPG 179/1182
# Processed image: G3929482.JPG 180/1182
# Processed image: G3929483.JPG 181/1182
# Processed image: G3929485.JPG 182/1182
# Processed image: G3929486.JPG 183/1182
# Processed image: G3929487.JPG 184/1182
# Processed image: G3929488.JPG 185/1182
# Processed image: G3939489.JPG 186/1182
# Processed image: G3939490.JPG 187/1182
# Processed image: G3939491.JPG 188/1182
# Processed image: G3939492.JPG 189/1182
# Processed image: G3939493.JPG 190/1182
# Processed image: G3939494.JPG 191/1182
# Processed image: G3939495.JPG 192/1182
# Processed image: G3939496.JPG 193/1182
# Processed image: G3939497.JPG 194/1182
# Processed image: G3939498.JPG 195/1182
# Processed image: G3949499.JPG 196/1182
# Processed image: G3949500.JPG 197/1182
# Processed image: G3949501.JPG 198/1182
# Processed image: G3949502.JPG 199/1182
# Processed image: G3949505.JPG 200/1182
# Processed image: G3949506.JPG 201/1182
# Processed image: G3949507.JPG 202/1182
# Processed image: G3949508.JPG 203/1182
# Processed image: G3959509.JPG 204/1182
# Processed image: G3959510.JPG 205/1182
# Processed image: G0052050.JPG 206/1182
# Processed image: G0062054.JPG 207/1182
# Processed image: G0062055.JPG 208/1182
# Processed image: G0062056.JPG 209/1182
# Processed image: G0062057.JPG 210/1182
# Processed image: G0062058.JPG 211/1182
# Processed image: G0062059.JPG 212/1182
# Processed image: G0062060.JPG 213/1182
# Processed image: G0062061.JPG 214/1182
# Processed image: G0062062.JPG 215/1182
# Processed image: G0062063.JPG 216/1182
# Processed image: G0062064.JPG 217/1182
# Processed image: G0062065.JPG 218/1182
# Processed image: G0062066.JPG 219/1182
# Processed image: G0062067.JPG 220/1182
# Processed image: G0062068.JPG 221/1182
# Processed image: G0062069.JPG 222/1182
# Processed image: G0062070.JPG 223/1182
# Processed image: G0062071.JPG 224/1182
# Processed image: G0062072.JPG 225/1182
# Processed image: G0062073.JPG 226/1182
# Processed image: G0062074.JPG 227/1182
# Processed image: G0062075.JPG 228/1182
# Processed image: G0062076.JPG 229/1182
# Processed image: G0062077.JPG 230/1182
# Processed image: G0062078.JPG 231/1182
# Processed image: G0062079.JPG 232/1182
# Processed image: G0062080.JPG 233/1182
# Processed image: G0062081.JPG 234/1182
# Processed image: G0062082.JPG 235/1182
# Processed image: G0062083.JPG 236/1182
# Processed image: G0062084.JPG 237/1182
# Processed image: G0062085.JPG 238/1182
# Processed image: G0102098.JPG 239/1182
# Processed image: G0102099.JPG 240/1182
# Processed image: G0102100.JPG 241/1182
# Processed image: G0102101.JPG 242/1182
# Processed image: G0102102.JPG 243/1182
# Processed image: G0102103.JPG 244/1182
# Processed image: G0102104.JPG 245/1182
# Processed image: G0102105.JPG 246/1182
# Processed image: G0102106.JPG 247/1182
# Processed image: G0102107.JPG 248/1182
# Processed image: G0102108.JPG 249/1182
# Processed image: G0102109.JPG 250/1182
# Processed image: G0102110.JPG 251/1182
# Processed image: G0102111.JPG 252/1182
# Processed image: G0102112.JPG 253/1182
# Processed image: G0102113.JPG 254/1182
# Processed image: G0102114.JPG 255/1182
# Processed image: G0102115.JPG 256/1182
# Processed image: G0102116.JPG 257/1182
# Processed image: G0102117.JPG 258/1182
# Processed image: G0102118.JPG 259/1182
# Processed image: G0102119.JPG 260/1182
# Processed image: G0102120.JPG 261/1182
# Processed image: G0102121.JPG 262/1182
# Processed image: G0102122.JPG 263/1182
# Processed image: G0102123.JPG 264/1182
# Processed image: G0102124.JPG 265/1182
# Processed image: G0102125.JPG 266/1182
# Processed image: G0102126.JPG 267/1182
# Processed image: G0102127.JPG 268/1182
# Processed image: G0102128.JPG 269/1182
# Processed image: G0102129.JPG 270/1182
# Processed image: G0102130.JPG 271/1182
# Processed image: G0102131.JPG 272/1182
# Processed image: G0102132.JPG 273/1182
# Processed image: G0102133.JPG 274/1182
# Processed image: G0102134.JPG 275/1182
# Processed image: G0102135.JPG 276/1182
# Processed image: G0102136.JPG 277/1182
# Processed image: G0102137.JPG 278/1182
# Processed image: G0102138.JPG 279/1182
# Processed image: G0102139.JPG 280/1182
# Processed image: G0102140.JPG 281/1182
# Processed image: G0102141.JPG 282/1182
# Processed image: G0102142.JPG 283/1182
# Processed image: G0102143.JPG 284/1182
# Processed image: G0102144.JPG 285/1182
# Processed image: G0102145.JPG 286/1182
# Processed image: G0102146.JPG 287/1182
# Processed image: G0102147.JPG 288/1182
# Processed image: G0102148.JPG 289/1182
# Processed image: G0102149.JPG 290/1182
# Processed image: G0102150.JPG 291/1182
# Processed image: G0102151.JPG 292/1182
# Processed image: G0102152.JPG 293/1182
# Processed image: G0102153.JPG 294/1182
# Processed image: G0102154.JPG 295/1182
# Processed image: G0102155.JPG 296/1182
# Processed image: G0102156.JPG 297/1182
# Processed image: G0102157.JPG 298/1182
# Processed image: G0102158.JPG 299/1182
# Processed image: G0102159.JPG 300/1182
# Processed image: G0102160.JPG 301/1182
# Processed image: G0102161.JPG 302/1182
# Processed image: G0102162.JPG 303/1182
# Processed image: G0102163.JPG 304/1182
# Processed image: G0102164.JPG 305/1182
# Processed image: G0102165.JPG 306/1182
# Processed image: G0102166.JPG 307/1182
# Processed image: G0102167.JPG 308/1182
# Processed image: G0102168.JPG 309/1182
# Processed image: G0102169.JPG 310/1182
# Processed image: G0102170.JPG 311/1182
# Processed image: G0102171.JPG 312/1182
# Processed image: G0102172.JPG 313/1182
# Processed image: G0102173.JPG 314/1182
# Processed image: G0102174.JPG 315/1182
# Processed image: G0102175.JPG 316/1182
# Processed image: G0102176.JPG 317/1182
# Processed image: G0102177.JPG 318/1182
# Processed image: G0102178.JPG 319/1182
# Processed image: G0102179.JPG 320/1182
# Processed image: G0102180.JPG 321/1182
# Processed image: G0102181.JPG 322/1182
# Processed image: G0102182.JPG 323/1182
# Processed image: G0102183.JPG 324/1182
# Processed image: G0102184.JPG 325/1182
# Processed image: G0102185.JPG 326/1182
# Processed image: G0102186.JPG 327/1182
# Processed image: G0102187.JPG 328/1182
# Processed image: G0102188.JPG 329/1182
# Processed image: G0102189.JPG 330/1182
# Processed image: G0102190.JPG 331/1182
# Processed image: G0102191.JPG 332/1182
# Processed image: G0102192.JPG 333/1182
# Processed image: G0102193.JPG 334/1182
# Processed image: G0102194.JPG 335/1182
# Processed image: G0102195.JPG 336/1182
# Processed image: G0102196.JPG 337/1182
# Processed image: G0102197.JPG 338/1182
# Processed image: G0102198.JPG 339/1182
# Processed image: G0102199.JPG 340/1182
# Processed image: G0102200.JPG 341/1182
# Processed image: G0102201.JPG 342/1182
# Processed image: G0102202.JPG 343/1182
# Processed image: G0102203.JPG 344/1182
# Processed image: G0102204.JPG 345/1182
# Processed image: G0102205.JPG 346/1182
# Processed image: G0102206.JPG 347/1182
# Processed image: G0102207.JPG 348/1182
# Processed image: G0102208.JPG 349/1182
# Processed image: G0102209.JPG 350/1182
# Processed image: G0112210.JPG 351/1182
# Processed image: G0112211.JPG 352/1182
# Processed image: G0112212.JPG 353/1182
# Processed image: G0112213.JPG 354/1182
# Processed image: G0112214.JPG 355/1182
# Processed image: G0112215.JPG 356/1182
# Processed image: G0112216.JPG 357/1182
# Processed image: G0112217.JPG 358/1182
# Processed image: G0112218.JPG 359/1182
# Processed image: G0112219.JPG 360/1182
# Processed image: G0112220.JPG 361/1182
# Processed image: G0112221.JPG 362/1182
# Processed image: G0112222.JPG 363/1182
# Processed image: G0112223.JPG 364/1182
# Processed image: G0112224.JPG 365/1182
# Processed image: G0112225.JPG 366/1182
# Processed image: G0112226.JPG 367/1182
# Processed image: G0112227.JPG 368/1182
# Processed image: G0112228.JPG 369/1182
# Processed image: G0112229.JPG 370/1182
# Processed image: G0112230.JPG 371/1182
# Processed image: G0112231.JPG 372/1182
# Processed image: G0112232.JPG 373/1182
# Processed image: G0112233.JPG 374/1182
# Processed image: G0112234.JPG 375/1182
# Processed image: G0112235.JPG 376/1182
# Processed image: G0112236.JPG 377/1182
# Processed image: G0112237.JPG 378/1182
# Processed image: G0112238.JPG 379/1182
# Processed image: G0112239.JPG 380/1182
# Processed image: G0112240.JPG 381/1182
# Processed image: G0112241.JPG 382/1182
# Processed image: G0112242.JPG 383/1182
# Processed image: G0112243.JPG 384/1182
# Processed image: G0112244.JPG 385/1182
# Processed image: G0112245.JPG 386/1182
# Processed image: G0112246.JPG 387/1182
# Processed image: GOPR1961.JPG 388/1182
# Processed image: GOPR1962.JPG 389/1182
# Processed image: GOPR1963.JPG 390/1182
# Processed image: GOPR1964.JPG 391/1182
# Processed image: GOPR1965.JPG 392/1182
# Processed image: GOPR1966.JPG 393/1182
# Processed image: GOPR1967.JPG 394/1182
# Processed image: GOPR1968.JPG 395/1182
# Processed image: GOPR1969.JPG 396/1182
# Processed image: GOPR1970.JPG 397/1182
# Processed image: GOPR1971.JPG 398/1182
# Processed image: GOPR1972.JPG 399/1182
# Processed image: G1665836.JPG 400/1182
# Processed image: G1665837.JPG 401/1182
# Processed image: G1665838.JPG 402/1182
# Processed image: G1665839.JPG 403/1182
# Processed image: G1665840.JPG 404/1182
# Processed image: G1665841.JPG 405/1182
# Processed image: G1665842.JPG 406/1182
# Processed image: G1665843.JPG 407/1182
# Processed image: G1665844.JPG 408/1182
# Processed image: G1665845.JPG 409/1182
# Processed image: G1675846.JPG 410/1182
# Processed image: G1675847.JPG 411/1182
# Processed image: G1675848.JPG 412/1182
# Processed image: G1675849.JPG 413/1182
# Processed image: G1675850.JPG 414/1182
# Processed image: G1675851.JPG 415/1182
# Processed image: G1675852.JPG 416/1182
# Processed image: G1675853.JPG 417/1182
# Processed image: G1675854.JPG 418/1182
# Processed image: G1675855.JPG 419/1182
# Processed image: G1685856.JPG 420/1182
# Processed image: G1685857.JPG 421/1182
# Processed image: G1685858.JPG 422/1182
# Processed image: G1685859.JPG 423/1182
# Processed image: G1685860.JPG 424/1182
# Processed image: G1685861.JPG 425/1182
# Processed image: G1685862.JPG 426/1182
# Processed image: G1685863.JPG 427/1182
# Processed image: G1685864.JPG 428/1182
# Processed image: G1685865.JPG 429/1182
# Processed image: G1695866.JPG 430/1182
# Processed image: G1695867.JPG 431/1182
# Processed image: G1695868.JPG 432/1182
# Processed image: G1695869.JPG 433/1182
# Processed image: G1695870.JPG 434/1182
# Processed image: G1695871.JPG 435/1182
# Processed image: G1695872.JPG 436/1182
# Processed image: G1695873.JPG 437/1182
# Processed image: G1695874.JPG 438/1182
# Processed image: G1695875.JPG 439/1182
# Processed image: G1705876.JPG 440/1182
# Processed image: G1705877.JPG 441/1182
# Processed image: G1705878.JPG 442/1182
# Processed image: G1705879.JPG 443/1182
# Processed image: G1705880.JPG 444/1182
# Processed image: G1705881.JPG 445/1182
# Processed image: G1705882.JPG 446/1182
# Processed image: G1705883.JPG 447/1182
# Processed image: G1705884.JPG 448/1182
# Processed image: G1705885.JPG 449/1182
# Processed image: G1715886.JPG 450/1182
# Processed image: G1715887.JPG 451/1182
# Processed image: G1715888.JPG 452/1182
# Processed image: G1715889.JPG 453/1182
# Processed image: G1715890.JPG 454/1182
# Processed image: G1715891.JPG 455/1182
# Processed image: G1715892.JPG 456/1182
# Processed image: G1715893.JPG 457/1182
# Processed image: G1715894.JPG 458/1182
# Processed image: G1715895.JPG 459/1182
# Processed image: G1725896.JPG 460/1182
# Processed image: G1725897.JPG 461/1182
# Processed image: G1725898.JPG 462/1182
# Processed image: G1725899.JPG 463/1182
# Processed image: G1725900.JPG 464/1182
# Processed image: G1725901.JPG 465/1182
# Processed image: G1725902.JPG 466/1182
# Processed image: G1725903.JPG 467/1182
# Processed image: G1725904.JPG 468/1182
# Processed image: G1725905.JPG 469/1182
# Processed image: G1735906.JPG 470/1182
# Processed image: G1735907.JPG 471/1182
# Processed image: G1735908.JPG 472/1182
# Processed image: G1735909.JPG 473/1182
# Processed image: G1735910.JPG 474/1182
# Processed image: G1735911.JPG 475/1182
# Processed image: G1735912.JPG 476/1182
# Processed image: G1735913.JPG 477/1182
# Processed image: G1735914.JPG 478/1182
# Processed image: G1735915.JPG 479/1182
# Processed image: G1745916.JPG 480/1182
# Processed image: G1745917.JPG 481/1182
# Processed image: G1745918.JPG 482/1182
# Processed image: G1745919.JPG 483/1182
# Processed image: G1745920.JPG 484/1182
# Processed image: G1745921.JPG 485/1182
# Processed image: G1745922.JPG 486/1182
# Processed image: G1745923.JPG 487/1182
# Processed image: G1745924.JPG 488/1182
# Processed image: G1745925.JPG 489/1182
# Processed image: G1755926.JPG 490/1182
# Processed image: G1755927.JPG 491/1182
# Processed image: G1755928.JPG 492/1182
# Processed image: G1755929.JPG 493/1182
# Processed image: G1755930.JPG 494/1182
# Processed image: G1755931.JPG 495/1182
# Processed image: G1755932.JPG 496/1182
# Processed image: G1755933.JPG 497/1182
# Processed image: G1755934.JPG 498/1182
# Processed image: G1755935.JPG 499/1182
# Processed image: G1765936.JPG 500/1182
# Processed image: G1765937.JPG 501/1182
# Processed image: G1765938.JPG 502/1182
# Processed image: G1765939.JPG 503/1182
# Processed image: G1765940.JPG 504/1182
# Processed image: G1765941.JPG 505/1182
# Processed image: G1765942.JPG 506/1182
# Processed image: G1765943.JPG 507/1182
# Processed image: G1765944.JPG 508/1182
# Processed image: G1765945.JPG 509/1182
# Processed image: G1775946.JPG 510/1182
# Processed image: G1775947.JPG 511/1182
# Processed image: G1775948.JPG 512/1182
# Processed image: G1775949.JPG 513/1182
# Processed image: G1775950.JPG 514/1182
# Processed image: G1775951.JPG 515/1182
# Processed image: G1775952.JPG 516/1182
# Processed image: G1775953.JPG 517/1182
# Processed image: G1775954.JPG 518/1182
# Processed image: G1775955.JPG 519/1182
# Processed image: G1785956.JPG 520/1182
# Processed image: G1785957.JPG 521/1182
# Processed image: G1785958.JPG 522/1182
# Processed image: G1785959.JPG 523/1182
# Processed image: G1785960.JPG 524/1182
# Processed image: G1785961.JPG 525/1182
# Processed image: G1785962.JPG 526/1182
# Processed image: G1785963.JPG 527/1182
# Processed image: G1785964.JPG 528/1182
# Processed image: G1785965.JPG 529/1182
# Processed image: G1795966.JPG 530/1182
# Processed image: G1795967.JPG 531/1182
# Processed image: G1795968.JPG 532/1182
# Processed image: G1795969.JPG 533/1182
# Processed image: G1795970.JPG 534/1182
# Processed image: G1795971.JPG 535/1182
# Processed image: G1795972.JPG 536/1182
# Processed image: G1795973.JPG 537/1182
# Processed image: G1795974.JPG 538/1182
# Processed image: G1795975.JPG 539/1182
# Processed image: G1805976.JPG 540/1182
# Processed image: G1805977.JPG 541/1182
# Processed image: G1805978.JPG 542/1182
# Processed image: G1805979.JPG 543/1182
# Processed image: G1805980.JPG 544/1182
# Processed image: G1805981.JPG 545/1182
# Processed image: G1805982.JPG 546/1182
# Processed image: G1805983.JPG 547/1182
# Processed image: G1805984.JPG 548/1182
# Processed image: G1805985.JPG 549/1182
# Processed image: G1815986.JPG 550/1182
# Processed image: G1815987.JPG 551/1182
# Processed image: G1815988.JPG 552/1182
# Processed image: G1815989.JPG 553/1182
# Processed image: G1815990.JPG 554/1182
# Processed image: G1815991.JPG 555/1182
# Processed image: G1815992.JPG 556/1182
# Processed image: G1815993.JPG 557/1182
# Processed image: G1815994.JPG 558/1182
# Processed image: G1815995.JPG 559/1182
# Processed image: G1825996.JPG 560/1182
# Processed image: G1825997.JPG 561/1182
# Processed image: G1825998.JPG 562/1182
# Processed image: G1825999.JPG 563/1182
# Processed image: G1826000.JPG 564/1182
# Processed image: G1826001.JPG 565/1182
# Processed image: G1826002.JPG 566/1182
# Processed image: G1826003.JPG 567/1182
# Processed image: G1826004.JPG 568/1182
# Processed image: G1826005.JPG 569/1182
# Processed image: G1836006.JPG 570/1182
# Processed image: G1836007.JPG 571/1182
# Processed image: G1836008.JPG 572/1182
# Processed image: G1836009.JPG 573/1182
# Processed image: G1836010.JPG 574/1182
# Processed image: G1836011.JPG 575/1182
# Processed image: G1836012.JPG 576/1182
# Processed image: G1836013.JPG 577/1182
# Processed image: G1836014.JPG 578/1182
# Processed image: G1836015.JPG 579/1182
# Processed image: G1846016.JPG 580/1182
# Processed image: G1846017.JPG 581/1182
# Processed image: G1846018.JPG 582/1182
# Processed image: G1846019.JPG 583/1182
# Processed image: G1846020.JPG 584/1182
# Processed image: G1846021.JPG 585/1182
# Processed image: G1846022.JPG 586/1182
# Processed image: G1846023.JPG 587/1182
# Processed image: G1846024.JPG 588/1182
# Processed image: G1846025.JPG 589/1182
# Processed image: G1856026.JPG 590/1182
# Processed image: G1856027.JPG 591/1182
# Processed image: G1856028.JPG 592/1182
# Processed image: G1856029.JPG 593/1182
# Processed image: G1856030.JPG 594/1182
# Processed image: G1856031.JPG 595/1182
# Processed image: G1856032.JPG 596/1182
# Processed image: G1856033.JPG 597/1182
# Processed image: G1856034.JPG 598/1182
# Processed image: G1856035.JPG 599/1182
# Processed image: G1866036.JPG 600/1182
# Processed image: G1866037.JPG 601/1182
# Processed image: G1866038.JPG 602/1182
# Processed image: G1866039.JPG 603/1182
# Processed image: G1866040.JPG 604/1182
# Processed image: G1866041.JPG 605/1182
# Processed image: G1866042.JPG 606/1182
# Processed image: G1866043.JPG 607/1182
# Processed image: G1866044.JPG 608/1182
# Processed image: G1866045.JPG 609/1182
# Processed image: G1876046.JPG 610/1182
# Processed image: G1876047.JPG 611/1182
# Processed image: G1876048.JPG 612/1182
# Processed image: G1876049.JPG 613/1182
# Processed image: G1876050.JPG 614/1182
# Processed image: G1876051.JPG 615/1182
# Processed image: G1876052.JPG 616/1182
# Processed image: G1876053.JPG 617/1182
# Processed image: G1876054.JPG 618/1182
# Processed image: G1876055.JPG 619/1182
# Processed image: G1886056.JPG 620/1182
# Processed image: G1886057.JPG 621/1182
# Processed image: G1886058.JPG 622/1182
# Processed image: G1886059.JPG 623/1182
# Processed image: G1886060.JPG 624/1182
# Processed image: G1886061.JPG 625/1182
# Processed image: G1886062.JPG 626/1182
# Processed image: G1886063.JPG 627/1182
# Processed image: G1886064.JPG 628/1182
# Processed image: G1886065.JPG 629/1182
# Processed image: G1896066.JPG 630/1182
# Processed image: G1896067.JPG 631/1182
# Processed image: G1896068.JPG 632/1182
# Processed image: G1896069.JPG 633/1182
# Processed image: G1896070.JPG 634/1182
# Processed image: G1896071.JPG 635/1182
# Processed image: G1896072.JPG 636/1182
# Processed image: G1896073.JPG 637/1182
# Processed image: G1896074.JPG 638/1182
# Processed image: G1896075.JPG 639/1182
# Processed image: G1906076.JPG 640/1182
# Processed image: G1906077.JPG 641/1182
# Processed image: G1906078.JPG 642/1182
# Processed image: G1906079.JPG 643/1182
# Processed image: G1906080.JPG 644/1182
# Processed image: G1906081.JPG 645/1182
# Processed image: G1906082.JPG 646/1182
# Processed image: G1906083.JPG 647/1182
# Processed image: G1906084.JPG 648/1182
# Processed image: G1906085.JPG 649/1182
# Processed image: G1916086.JPG 650/1182
# Processed image: G1916087.JPG 651/1182
# Processed image: G1916088.JPG 652/1182
# Processed image: G1916089.JPG 653/1182
# Processed image: G1916090.JPG 654/1182
# Processed image: G1916091.JPG 655/1182
# Processed image: G1916092.JPG 656/1182
# Processed image: G1916093.JPG 657/1182
# Processed image: G1916094.JPG 658/1182
# Processed image: G1916095.JPG 659/1182
# Processed image: G1926096.JPG 660/1182
# Processed image: G1926097.JPG 661/1182
# Processed image: G1926098.JPG 662/1182
# Processed image: G1926099.JPG 663/1182
# Processed image: G1926100.JPG 664/1182
# Processed image: G1926101.JPG 665/1182
# Processed image: G1926102.JPG 666/1182
# Processed image: G1926103.JPG 667/1182
# Processed image: G1926104.JPG 668/1182
# Processed image: G1926105.JPG 669/1182
# Processed image: G1936106.JPG 670/1182
# Processed image: G1936107.JPG 671/1182
# Processed image: G1936108.JPG 672/1182
# Processed image: G1936109.JPG 673/1182
# Processed image: G1936110.JPG 674/1182
# Processed image: G1936111.JPG 675/1182
# Processed image: G1936112.JPG 676/1182
# Processed image: G1936113.JPG 677/1182
# Processed image: G1936114.JPG 678/1182
# Processed image: G1936115.JPG 679/1182
# Processed image: G1946116.JPG 680/1182
# Processed image: G1946117.JPG 681/1182
# Processed image: G1946118.JPG 682/1182
# Processed image: G1946119.JPG 683/1182
# Processed image: G1946120.JPG 684/1182
# Processed image: G1946121.JPG 685/1182
# Processed image: G1946122.JPG 686/1182
# Processed image: G1946123.JPG 687/1182
# Processed image: G1946124.JPG 688/1182
# Processed image: G1946125.JPG 689/1182
# Processed image: G1956126.JPG 690/1182
# Processed image: G1956127.JPG 691/1182
# Processed image: G1956128.JPG 692/1182
# Processed image: G1956129.JPG 693/1182
# Processed image: G1956130.JPG 694/1182
# Processed image: G1956131.JPG 695/1182
# Processed image: G1956132.JPG 696/1182
# Processed image: G1956133.JPG 697/1182
# Processed image: G1956134.JPG 698/1182
# Processed image: G1956135.JPG 699/1182
# Processed image: G1966136.JPG 700/1182
# Processed image: G1966137.JPG 701/1182
# Processed image: G1966138.JPG 702/1182
# Processed image: G1966139.JPG 703/1182
# Processed image: G1966140.JPG 704/1182
# Processed image: G1966141.JPG 705/1182
# Processed image: G1966142.JPG 706/1182
# Processed image: G1966143.JPG 707/1182
# Processed image: G1966144.JPG 708/1182
# Processed image: G1966145.JPG 709/1182
# Processed image: G1976146.JPG 710/1182
# Processed image: G1976147.JPG 711/1182
# Processed image: G1976148.JPG 712/1182
# Processed image: G1976149.JPG 713/1182
# Processed image: G1976150.JPG 714/1182
# Processed image: G1976151.JPG 715/1182
# Processed image: G1976152.JPG 716/1182
# Processed image: G1976153.JPG 717/1182
# Processed image: G1976154.JPG 718/1182
# Processed image: G1976155.JPG 719/1182
# Processed image: G4369919.JPG 720/1182
# Processed image: G4369920.JPG 721/1182
# Processed image: G4369921.JPG 722/1182
# Processed image: G4369922.JPG 723/1182
# Processed image: G4369923.JPG 724/1182
# Processed image: G4369924.JPG 725/1182
# Processed image: G4369925.JPG 726/1182
# Processed image: G4369926.JPG 727/1182
# Processed image: G4369927.JPG 728/1182
# Processed image: G4369928.JPG 729/1182
# Processed image: G4379929.JPG 730/1182
# Processed image: G4379930.JPG 731/1182
# Processed image: G4379931.JPG 732/1182
# Processed image: G4379932.JPG 733/1182
# Processed image: G4379933.JPG 734/1182
# Processed image: G4379934.JPG 735/1182
# Processed image: G4379935.JPG 736/1182
# Processed image: G4379936.JPG 737/1182
# Processed image: G4379937.JPG 738/1182
# Processed image: G4379938.JPG 739/1182
# Processed image: G4389939.JPG 740/1182
# Processed image: G4389940.JPG 741/1182
# Processed image: G4389941.JPG 742/1182
# Processed image: G4389942.JPG 743/1182
# Processed image: G4389943.JPG 744/1182
# Processed image: G4389944.JPG 745/1182
# Processed image: G4389945.JPG 746/1182
# Processed image: G4389946.JPG 747/1182
# Processed image: G4389947.JPG 748/1182
# Processed image: G4389948.JPG 749/1182
# Processed image: G4399949.JPG 750/1182
# Processed image: G4399950.JPG 751/1182
# Processed image: G4399951.JPG 752/1182
# Processed image: G4399952.JPG 753/1182
# Processed image: G4399953.JPG 754/1182
# Processed image: G4399954.JPG 755/1182
# Processed image: G4399955.JPG 756/1182
# Processed image: G4399956.JPG 757/1182
# Processed image: G4399957.JPG 758/1182
# Processed image: G4399958.JPG 759/1182
# Processed image: G4409959.JPG 760/1182
# Processed image: G4409960.JPG 761/1182
# Processed image: G4409961.JPG 762/1182
# Processed image: G4409962.JPG 763/1182
# Processed image: G4409963.JPG 764/1182
# Processed image: G4409964.JPG 765/1182
# Processed image: G4409965.JPG 766/1182
# Processed image: G4409966.JPG 767/1182
# Processed image: G4409967.JPG 768/1182
# Processed image: G4409968.JPG 769/1182
# Processed image: G4419969.JPG 770/1182
# Processed image: G4419970.JPG 771/1182
# Processed image: G4419971.JPG 772/1182
# Processed image: G4419972.JPG 773/1182
# Processed image: G4419973.JPG 774/1182
# Processed image: G4419974.JPG 775/1182
# Processed image: G4419975.JPG 776/1182
# Processed image: G4419976.JPG 777/1182
# Processed image: G4419977.JPG 778/1182
# Processed image: G4419978.JPG 779/1182
# Processed image: G4429979.JPG 780/1182
# Processed image: G4429980.JPG 781/1182
# Processed image: G4429981.JPG 782/1182
# Processed image: G4429982.JPG 783/1182
# Processed image: G4429983.JPG 784/1182
# Processed image: G4429984.JPG 785/1182
# Processed image: G4429985.JPG 786/1182
# Processed image: G4429986.JPG 787/1182
# Processed image: G4429987.JPG 788/1182
# Processed image: G4429988.JPG 789/1182
# Processed image: G4439989.JPG 790/1182
# Processed image: G4439990.JPG 791/1182
# Processed image: G4439991.JPG 792/1182
# Processed image: G4439992.JPG 793/1182
# Processed image: G4439993.JPG 794/1182
# Processed image: G4439994.JPG 795/1182
# Processed image: G4439995.JPG 796/1182
# Processed image: G4439996.JPG 797/1182
# Processed image: G4439997.JPG 798/1182
# Processed image: G4439998.JPG 799/1182
# Processed image: G4449999.JPG 800/1182
# Processed image: G4450001.JPG 801/1182
# Processed image: G4450002.JPG 802/1182
# Processed image: G4450003.JPG 803/1182
# Processed image: G4450004.JPG 804/1182
# Processed image: G4450005.JPG 805/1182
# Processed image: G4450006.JPG 806/1182
# Processed image: G4450007.JPG 807/1182
# Processed image: G4450008.JPG 808/1182
# Processed image: G4450009.JPG 809/1182
# Processed image: G4460010.JPG 810/1182
# Processed image: G4460011.JPG 811/1182
# Processed image: G4460012.JPG 812/1182
# Processed image: G4460013.JPG 813/1182
# Processed image: G4460014.JPG 814/1182
# Processed image: G4460015.JPG 815/1182
# Processed image: G4460016.JPG 816/1182
# Processed image: G4460017.JPG 817/1182
# Processed image: G4460018.JPG 818/1182
# Processed image: G4460019.JPG 819/1182
# Processed image: G4470020.JPG 820/1182
# Processed image: G4470021.JPG 821/1182
# Processed image: G4470022.JPG 822/1182
# Processed image: G4470023.JPG 823/1182
# Processed image: G4470024.JPG 824/1182
# Processed image: G4470025.JPG 825/1182
# Processed image: G4470026.JPG 826/1182
# Processed image: G4470027.JPG 827/1182
# Processed image: G4470028.JPG 828/1182
# Processed image: G4470029.JPG 829/1182
# Processed image: G4480030.JPG 830/1182
# Processed image: G4480031.JPG 831/1182
# Processed image: G4480032.JPG 832/1182
# Processed image: G4480033.JPG 833/1182
# Processed image: G4480034.JPG 834/1182
# Processed image: G4480035.JPG 835/1182
# Processed image: G4480036.JPG 836/1182
# Processed image: G4480037.JPG 837/1182
# Processed image: G4480038.JPG 838/1182
# Processed image: G4480039.JPG 839/1182
# Processed image: G4490040.JPG 840/1182
# Processed image: G4490041.JPG 841/1182
# Processed image: G4490042.JPG 842/1182
# Processed image: G4490043.JPG 843/1182
# Processed image: G4490044.JPG 844/1182
# Processed image: G4490045.JPG 845/1182
# Processed image: G4490046.JPG 846/1182
# Processed image: G4490047.JPG 847/1182
# Processed image: G4490048.JPG 848/1182
# Processed image: G4490049.JPG 849/1182
# Processed image: G4500050.JPG 850/1182
# Processed image: G4500051.JPG 851/1182

# %%
# !zip -r /content/output_WaterNet.zip /content/output_WaterNet

# %%
files.download('/content/output_WaterNet.zip')

# %% [markdown]
# ## Results Visualization

# %%
imgs_out = sorted(glob.glob("/content/output_WaterNet/*"))

# %%
fig, ax = plt.subplots(ncols=2, figsize=(30, 30))
im = cv2.imread(imgs[0])
im = cv2.resize(im, (800, 600))

ax[0].imshow(im)
ax[0].set_title("Original image")

out_img = cv2.imread(imgs_out[0])
out_img = cv2.resize(out_img, (800, 600))

ax[1].imshow(out_img)
ax[1].set_title("WaterNet")

plt.show()

# %% [markdown]
# ### Edges Visualization

# %%
edg_out = cv2.Canny(out_img,100,200)
edg_in = cv2.Canny(im,100,200)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 10))
ax[0].imshow(edg_in)
ax[0].axis("off")
ax[0].set_title("Original image")

ax[1].imshow(edg_out)
ax[1].axis("off")
ax[1].set_title("WaterNet output")

plt.show()

# %% [markdown]
# ## Evalution Metrics Functions

# %%
# source: https://github.com/Riccellisp/ProjetoPecem/blob/ba8c5e7b991e93044e3c86c42e48d3df4c9595fb/metrics.py

from skimage.metrics import structural_similarity as ssim
from skimage import color,filters
import numpy as np
import math
import sys

def plipsum(i,j,gamma=1026):
    return i + j - i * j / gamma

def plipsub(i,j,k=1026):
    return k * (i - j) / (k - j)

def plipmult(c,j,gamma=1026):
    return gamma - gamma * (1 - j / gamma)**c

def logamee(ch,blocksize=8):

    num_x = math.ceil(ch.shape[0] / blocksize)
    num_y = math.ceil(ch.shape[1] / blocksize)

    s = 0
    w = 1. / (num_x * num_y)
    for i in range(num_x):

        xlb = i * blocksize
        if i < num_x - 1:
            xrb = (i+1) * blocksize
        else:
            xrb = ch.shape[0]

        for j in range(num_y):

            ylb = j * blocksize
            if j < num_y - 1:
                yrb = (j+1) * blocksize
            else:
                yrb = ch.shape[1]

            block = ch[xlb:xrb,ylb:yrb]
            blockmin = float(np.min(block))
            blockmax = float(np.max(block))

            top = plipsub(blockmax,blockmin)
            bottom = plipsum(blockmax,blockmin)

            # if bottom == 0, result == 0
            m = bottom and top / bottom or 0
            if m ==0.:
                s+=0
            else:
                s += (m) * np.log(m)

    return plipmult(w,s)

def eme(img,rowSample,columnSample):

	grayImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

	rowSize, columnSize = grayImg.shape
	nRows = int(rowSize/rowSample)
	nColumns = int(columnSize/columnSample)
	incompleteRow = math.ceil(rowSize/rowSample) - nRows
	incompleteColumn = math.ceil(columnSize/columnSample) - nColumns

	somatory = 0
	nBlocks = nRows*nColumns
	for i in range(0,nRows):
		for j in range(0,nColumns):
			imax=grayImg[i*rowSample:(i+1)*rowSample,j*columnSample:(j+1)*rowSample].max()
			imin=grayImg[i*rowSample:(i+1)*rowSample,j*columnSample:(j+1)*rowSample].min()
			if imin==0:
				imin=1
			if imax==0:
				imax=1
			somatory = somatory + 20*math.log(imax/imin)

	if incompleteColumn==1:
		for i in range(0,nRows):
			imax=grayImg[i*rowSample:(i+1)*rowSample,nColumns*columnSample:columnSize].max()
			imin=grayImg[i*rowSample:(i+1)*rowSample,nColumns*columnSample:columnSize].min()
			if imin==0:
				imin=1
			if imax==0:
				imax=1
			somatory = somatory + 20*math.log(imax/imin)
			nBlocks = nBlocks + 1
	if incompleteRow==1:
		for j in range(0,nColumns):
			imax=grayImg[grayImg[nRows*rowSample:rowSize,j*columnSample:(j+1)*columnSample]].max()
			imin=grayImg[grayImg[nRows*rowSample:rowSize,j*columnSample:(j+1)*columnSample]].min()
			if imin==0:
				imin=1
			if imax==0:
				imax=1
			somatory = somatory + 20*math.log(imax/imin)
			nBlocks = nBlocks + 1
	if incompleteRow==1 and incompleteColumn==1:
		imax=grayImg[nRows*rowSample:rowSize,nColumns*columnSample:columnSize].max()
		imin=grayImg[nRows*rowSample:rowSize,nColumns*columnSample:columnSize].max()
		if imin==0:
			imin=1
		if imax==0:
			imax=1
		somatory = somatory + 20*math.log(imax/imin)
		nBlocks = nBlocks + 1
	return somatory/nBlocks

def UCIQE(a,c1=0.4680,c2 = 0.2745,c3 = 0.2576):
    """
    Underwater colour image quality evaluation metric (UCIQE) é uma métrica baseada na combinação
    linear de croma (pureza), saturação e contraste principalmente de imagens subaquáticas, mas também
    baseadaem trabalhos atuais de avaliação de imagens coloridas atmosféricas.
    REF: M. Yang and A. Sowmya, "An Underwater Color Image Quality Evaluation Metric," in IEEE Transactions on Image Processing,
    vol. 24, no. 12, pp. 6062-6071, Dec. 2015, doi: 10.1109/TIP.2015.2491020.
    :param a: imagem de entrada
    :c1,c2,c3: coeficentes ponderados
    :return c1 * sc + c2 * conl + c3 * us
    """
    rgb = a
    lab = color.rgb2lab(a)
    l = lab[:,:,0]

    #1st term
    chroma = (lab[:,:,1]**2 + lab[:,:,2]**2)**0.5
    uc = np.mean(chroma)
    sc = (np.mean((chroma - uc)**2))**0.5

    #2nd term
    top = int(np.round(0.01*l.shape[0]*l.shape[1]))
    sl = np.sort(l,axis=None)
    isl = sl[::-1]
    conl = np.mean(isl[:top])-np.mean(sl[:top])

    #3rd term
    satur = []
    chroma1 = chroma.flatten()
    l1 = l.flatten()
    for i in range(len(l1)):
      if chroma1[i] == 0: satur.append(0)
      elif l1[i] == 0: satur.append(0)
      else: satur.append(chroma1[i] / l1[i])

    us = np.mean(satur)

    return  c1 * sc + c2 * conl + c3 * us

def UIQM(a,p1=0.0282,p2=0.2953,p3=3.5753):
    """
    REF: K. Panetta, C. Gao and S. Agaian, Human-Visual-System-Inspired Underwater Image Quality Measures,
    in IEEE Journal of Oceanic Engineering, vol. 41, no. 3, pp. 541-551, July 2016, doi: 10.1109/JOE.2015.2469915.
    Metrica sem referencia, semelhante a UCIQE, mas mais atual. Leva em consideração a medida de colorção,
    medida de nitidez e medida de contraste.
    """
    #1st term UICM
    #TαL=⌈αLK⌉ - > o inteiro mais próximo maior ou igual a αLK
    #TαR=⌊αRK⌋ - > o inteiro mais próximo menor ou igual a αRK
    rgb=a
    gray = color.rgb2gray(a)
    rg = rgb[:,:,0] - rgb[:,:,1]
    yb = (rgb[:,:,0] + rgb[:,:,1]) / 2 - rgb[:,:,2]
    rgl = np.sort(rg,axis=None)
    ybl = np.sort(yb,axis=None)
    al1 = 0.1
    al2 = 0.1
    T1 = int(al1 * len(rgl))
    T2 = int(al2 * len(rgl))
    rgl_tr = rgl[T1:-T2]
    ybl_tr = ybl[T1:-T2]

    urg = np.mean(rgl_tr) # μ^2_α,RG
    s2rg = np.mean((rgl_tr - urg) ** 2)  # σ2α,RG
    uyb = np.mean(ybl_tr) # μ^2_α,YB
    s2yb = np.mean((ybl_tr- uyb) ** 2) # σ2α,YB

    uicm =-0.0268 * np.sqrt(urg**2 + uyb**2) + 0.1586 * np.sqrt(s2rg + s2yb)

    #2nd term UISM (k1k2=8x8)   # medida de nitidez de imagem
    """Para medir a nitidez nas bordas, o detector de bordas Sobel é aplicado primeiro em cada componente de cor RGB
      O mapa de arestas resultante é então multiplicado pela imagem original para obter o mapa de arestas em tons de cinza."""
    # Rsobel = rgb[:,:,0] * filters.sobel(rgb[:,:,0])
    # Gsobel = rgb[:,:,1] * filters.sobel(rgb[:,:,1])
    # Bsobel = rgb[:,:,2] * filters.sobel(rgb[:,:,2])

    # Rsobel=np.round(Rsobel).astype(np.uint8)  # Arredonda a matriz para numeros inteiros
    # Gsobel=np.round(Gsobel).astype(np.uint8)
    # Bsobel=np.round(Bsobel).astype(np.uint8)

    Reme = eme(a,8,8)
    Geme = eme(a,8,8)
    Beme = eme(a,8,8)
    uism = 0.299 * Reme + 0.587 * Geme + 0.114 * Beme

    #3rd term UIConM
    uiconm = logamee(gray)
    uiqm = p1 * uicm + p2 * uism + p3 * uiconm

    return uiqm

def CCF(imageRGB):
	"""REF:
	@article{WANG2018904,
	title = {An imaging-inspired no-reference underwater color image quality assessment metric},
	journal = {Computers & Electrical Engineering},
	volume = {70},
	pages = {904-913},
	year = {2018},
	issn = {0045-7906},
	doi = {https://doi.org/10.1016/j.compeleceng.2017.12.006},
	url = {https://www.sciencedirect.com/science/article/pii/S0045790617324953},
	author = {Yan Wang and Na Li and Zongying Li and Zhaorui Gu and Haiyong Zheng and Bing Zheng and Mengnan Sun},
	keywords = {No-reference image quality assessment, Underwater imaging, Underwater image, Underwater color image quality},
	abstract = {Underwater color image quality assessment (IQA) plays an important role in analysis and applications of underwater imaging as well as image processing algorithms. This paper presents a new metric inspired by the imaging analysis on underwater absorption and scattering characteristics, dubbed the CCF. This metric is feature-weighted with a combination of colorfulness index, contrast index and fog density index, which can quantify the color loss caused by absorption, the blurring caused by forward scattering and the foggy caused by backward scattering, respectively. Then multiple linear regression is used to calculate three weighted coefficients. A new underwater image database is built to illustrate the performance of the proposed metric. Experimental results show a strong correlation between the proposed metric and mean opinion score (MOS). The proposed CCF metric outperforms many of the leading atmospheric IQA metrics, and it can effectively assess the performance of underwater image enhancement and image restoration methods.}
	}

	Métrica sem referência. Essa métrica é ponderada por recursos com uma combinação de índice de colorido,
	índice de contraste e índice de densidade de neblina, que pode quantificar a perda de cor
	causada pela absorção, o desfoque causado pela dispersão para frente e o nevoeiro causado
	pela dispersão para trás, respectivamente.
	"""
  # Rij=np.log(rgb[:,:,0])-np.mean(rgb[:,:,0], out=np.zeros_like(rgb[:,:,0])-np.mean(rgb[:,:,0]), where=(rgb[:,:,0])-np.mean(rgb[:,:,0]!=0))
	# Gij=np.log(rgb[:,:,1])-np.mean(rgb[:,:,1], out=np.zeros_like(rgb[:,:,1])-np.mean(rgb[:,:,1]), where=(rgb[:,:,1])-np.mean(rgb[:,:,1]!=0))
	# Bij=np.log(rgb[:,:,2])-np.mean(rgb[:,:,2], out=np.zeros_like(rgb[:,:,2])-np.mean(rgb[:,:,2]), where=(rgb[:,:,2])-np.mean(rgb[:,:,2]!=0))
	rgb=imageRGB
	gray = color.rgb2gray(imageRGB)
	# Passo 1
	Rij=np.log(rgb[:,:,0])-np.mean(rgb[:,:,0])
	Gij=np.log(rgb[:,:,1])-np.mean(rgb[:,:,1])
	Bij=np.log(rgb[:,:,2])-np.mean(rgb[:,:,2])

	# Passo 2
	a = rgb[:,:,0] - rgb[:,:,1]
	b = (rgb[:,:,0] + rgb[:,:,1]) / 2 - rgb[:,:,2]

	var_a  = np.var(a)
	var_b  = np.var(b)
	mean_a = np.mean(a)
	mean_b = np.mean(b)

	ccf=(math.sqrt(var_a+var_b)+0.3*math.sqrt(var_a+var_b)) /85.59


	return ccf

# %%
UIQM_list, UCIQE_list, CCF_list  = list(), list(), list()
UIQM_out_list, UCIQE_out_list, CCF_out_list  = list(), list(), list()
for img in imgs:
  im = cv2.imread(img)
  im = cv2.resize(im, (800, 600))
  UIQM_list.append(UIQM(im))
  UCIQE_list.append(UCIQE(im))
  CCF_list.append(CCF(im))

for img in imgs_out:
  im = cv2.imread(img)
  im = cv2.resize(im, (800, 600))
  UIQM_out_list.append(UIQM(im))
  UCIQE_out_list.append(UCIQE(im))
  CCF_out_list.append(CCF(im))

# %%
np.mean(UIQM_list), np.std(UIQM_list)

# %%
np.mean(UCIQE_list), np.std(UCIQE_list)

# %%
np.mean(CCF_list), np.std(CCF_list)

# %%
np.mean(UIQM_out_list), np.std(UIQM_out_list)

# %%
np.mean(UCIQE_out_list), np.std(UCIQE_out_list)

# %%
np.mean(CCF_out_list), np.std(CCF_out_list)

# %%
# !zip -r /content/output_WaterNet.zip /content/output_WaterNet
